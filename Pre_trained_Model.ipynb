# %% [markdown]
# <a href="https://colab.research.google.com/github/Areeb-07/WiDS-ACD/blob/main/Pre_trained_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# Cloning Repository
#
# Installing Dependencies
#
# Checking PyTorch and GPU

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-132-g014acde torch 1.10.0+cu111 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.8/107.7 GB disk)

# %% [markdown]
# ## Mounting Drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/data/training_images
# Out:
# /content/drive/My Drive/data/training_images

# %% [markdown]
# ## Copying Files from Drive to Folder 'images'

# %% [markdown]
# There are 418 files named vid_4_{some number}.jpg
#
# These numbers range from 600 to 30440 but they do not change continuously
#
# The following command tries to copy files with all the numbers in the range

# %%
# !bash -c 'cp vid_4_{600..30440}.jpg /content/yolov5/data/images'
# Out:
# Streaming output truncated to the last 5000 lines.
# cp: cannot stat 'vid_4_25328.jpg': No such file or directory
# cp: cannot stat 'vid_4_25329.jpg': No such file or directory
# cp: cannot stat 'vid_4_25330.jpg': No such file or directory
# cp: cannot stat 'vid_4_25331.jpg': No such file or directory
# cp: cannot stat 'vid_4_25332.jpg': No such file or directory
# cp: cannot stat 'vid_4_25333.jpg': No such file or directory
# cp: cannot stat 'vid_4_25334.jpg': No such file or directory
# cp: cannot stat 'vid_4_25335.jpg': No such file or directory
# cp: cannot stat 'vid_4_25336.jpg': No such file or directory
# cp: cannot stat 'vid_4_25337.jpg': No such file or directory
# cp: cannot stat 'vid_4_25338.jpg': No such file or directory
# cp: cannot stat 'vid_4_25339.jpg': No such file or directory
# cp: cannot stat 'vid_4_25340.jpg': No such file or directory
# cp: cannot stat 'vid_4_25341.jpg': No such file or directory
# cp: cannot stat 'vid_4_25342.jpg': No such file or directory
# ...

# %% [markdown]
# These lines are shown for numbers from the range that do not correspond to any file
#
# There are 29433 such numbers
#
# However, we can ignore this as our task is completed
#
# All the files have been successfully copied to the folder

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %% [markdown]
# # Detecting Objects in the Images

# %% [markdown]
# detect.py runs YOLOv5 inference on a variety of sources, downloading models automatically from the latest YOLOv5 release, and saving results to runs/detect
#
# The following command detects objects in all the images present in the folder 'images'
#
# After detecting objects in all the images, it will also give an example of object detection performed as an image

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
display.Image(filename='runs/detect/exp8/vid_4_600.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-132-g014acde torch 1.10.0+cu111 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/420 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.368s)
# image 2/420 /content/yolov5/data/images/vid_4_22960.jpg: 384x640 Done. (0.260s)
# image 3/420 /content/yolov5/data/images/vid_4_22980.jpg: 384x640 1 car, Done. (0.243s)
# image 4/420 /content/yolov5/data/images/vid_4_2300.jpg: 384x640 Done. (0.254s)
# ...

# %% [markdown]
# The image now contains the bounding boxes used in object detection

# %% [markdown]
# # Further Examples

# %% [markdown]
# #### Image 2

# %%
display.Image(filename='runs/detect/exp8/vid_4_700.jpg', width=600)

# %% [markdown]
# #### Image 3

# %%
display.Image(filename='runs/detect/exp8/vid_4_3360.jpg', width=600)

# %% [markdown]
# #### Image 4

# %%
display.Image(filename='runs/detect/exp8/vid_4_4400.jpg', width=600)

# %% [markdown]
# #### Image 5

# %%
display.Image(filename='runs/detect/exp8/vid_4_6280.jpg', width=600)

# %% [markdown]
# #### Image 6

# %%
display.Image(filename='runs/detect/exp8/vid_4_26380.jpg', width=600)

# %% [markdown]
# #### Image 7

# %%
display.Image(filename='runs/detect/exp8/vid_4_30440.jpg', width=600)

# %% [markdown]
# #### Image 8

# %%
display.Image(filename='runs/detect/exp8/vid_4_8700.jpg', width=600)

# %% [markdown]
# #### Image 9

# %%
display.Image(filename='runs/detect/exp8/vid_4_24760.jpg', width=600)

# %% [markdown]
# #### Image 10

# %%
display.Image(filename='runs/detect/exp8/vid_4_9760.jpg', width=600)
